# %% [markdown]
# <a href="https://colab.research.google.com/github/Nattakonjpg/BasicProg_DataViz65/blob/main/DataViz01_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv")

# %%
df

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df["Name"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# #Parallel

# %%
pd.plotting.parallel_coordinates(df, "Name")

# %% [markdown]
# #select Columns to show

# %%
pd.plotting.parallel_coordinates(df, "Name", color=["Sepallength", "Petalength", "Sepalwidth", "Petawidth"])

# %%
pd.plotting.parallel_coordinates(df, "Name", color=["r","y","k"])

# %%
pd.plotting.parallel_coordinates(df, "Name", color=["c","m","k"])

# %%
pd.plotting.parallel_coordinates(df, "Name", color=["#A73B24","#2EFA2E","#88B46C"])
